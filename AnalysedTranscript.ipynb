# %% [markdown]
# # Analyzing Your Transcript: Speech Turns and Dictionaries
#
# **NOTE:** Click [here](https://colab.research.google.com/github/senthilchandrasegaran/IDEM105-EDI/blob/main/03-reading-transcript-files.ipynb) to open the file in Colab.

# %% [markdown]
# ## Load Transcript Text
# Let's load your Transcript file from BrightSpace. Download your file and save it in a folder that allows you to load the file into this Notebook.
# If you are using Colab, you would need to first upload the file to Google Drive and then specify the link in the `read_excel` command below.
#
# Since this is an excel file, you will need to use a python library called *pandas* to read and process files as tables or "DataFrames".

# %%
import pandas as pd
# Use 'pd' as a shortcut for 'pandas' as it saves you the effort of typing 'pandas' every time.

# %% [markdown]
# It is convention to add a `_df` suffix to all variables that represent dataframes. So we load the transcript into a variable called `transcript_df`.

# %%
transcript_df = pd.read_excel('/content/Transcript bewerkt-final.xlsx')
# Print a random sample of the dataframe, showing 5 rows.
transcript_df.sample(5)
# Out:
#      Unnamed: 0 timestamp        speaker  \
# 360         360  00:26:04   Jasmijn Miog
# 578         578  00:47:59   Jasmijn Miog
# 552         552  00:45:03  Sarah Duister
# 302         302  00:21:12   Jasmijn Miog
# 566         566  00:47:09   Jasmijn Miog
#
#                                              utterance
# 360                            Those are more heavily.
# 578  I also hear occasional stories about harassmen...
# 552                                       Wait, sorry.
# 302    She, like the wide pathways and well lit areas.
# 566  They are going there for jogging or a peaceful...

# %% [markdown]
# This format is helpful, because just like we do in excel, we can count the rows, filter the table by a particular column value, and other manipulations of the table. We will explore a few of these approaches, but only in the context of what we are interested in, i.e., the analysis of the conversation recorded as the transcript.
#
# For instance, we can check how many speech turns (i.e., rows in the excel sheet) have been captured in the transcript.

# %%
print("Total number of speech turns : ", transcript_df.shape[0])
# Out:
# Total number of speech turns :  1151

# %% [markdown]
# ## Analyzing participation
# Participation in a conversation is very subjective, and thus there is no one objective measure for it. However, we can explore a few aspects of participation. These could be the number of "speech turns", or the number of times a speaker spoke, or "utterance length": which could be how long (in time) a speaker spoke, or how long (in words) their utterances were.
#
# ### Number of Speech Turns
# Let's start simple. Who had the most speech turns?

# %%
# Let's first get a list of speakers attributed to each speech turn.
speakers = transcript_df['speaker'].to_list()

# We use the 'Counter' function from the 'collections' library to count the number of speech turns by speaker.
from collections import Counter
speaker_turn_counts = Counter(speakers)
print(speaker_turn_counts)
# Out:
# Counter({'Sarah Duister': 442, 'Tessel Pluym': 372, 'Jasmijn Miog': 337})

# %% [markdown]
# ---
#
# #### NOTE:
# If you see any cases of misspelled speakers, or speaker names you think are wrong, it would be apparent in the above list.
#
# Go back to the excel file, fix the speakers if necessary, and run the above cells again until you get only the expected number of speakers.
#
# ---

# %% [markdown]
# #### Plotting the result
# We can also plot the speech turns for a nice graphical representation.
# First, let's create a new dataframe with the calculated information.

# %%
# Convert the 'counter' object that we have called `speaker_turn_counts' into a table, and then plot it.
turns_df = pd.DataFrame.from_dict(speaker_turn_counts, orient='index').reset_index()
turns_df
# Out:
#            index    0
# 0  Sarah Duister  442
# 1   Jasmijn Miog  337
# 2   Tessel Pluym  372

# %% [markdown]
# The column headers look awkward, so we can rename them.

# %%
turns_df = turns_df.rename(columns={"index": "Speaker", 0: "Turns"})
turns_df
# Out:
#          Speaker  Turns
# 0  Sarah Duister    442
# 1   Jasmijn Miog    337
# 2   Tessel Pluym    372

# %%
# Import the plotting library
import matplotlib.pyplot as plt
import seaborn as sns

scale = 0.6
figure_height = turns_df.shape[0] * scale
figure_width = figure_height * 3 * scale
plt.figure(figsize=(figure_width, figure_height))
g = sns.barplot(data=turns_df, x="Turns", y="Speaker", color='gray')

# %% [markdown]
# ## Tokenization & Word Count
# Last week, we tried tokenization of the entire transcript. This time, let's do it by speech turn.

# %%
import nltk
nltk.download('punkt_tab')  # comment this line after the first time you run this code.
from nltk import word_tokenize

# Make a list of all utterances in the transcript
utterances_list = transcript_df['utterance'].to_list()

# Iterate over this list and tokenize every utterance, saving the utterances as one list,
# and corresponding word counts as another list.
utterance_tokenized_list = []
utterance_word_counts = []
for utterance in utterances_list :
    tokens = word_tokenize(utterance)
    word_count = len(tokens)
    utterance_tokenized_list.append(tokens)
    utterance_word_counts.append(word_count)

# Add the new information to the existing dataframe as a new column.
transcript_df['utterance_tokens'] = utterance_tokenized_list
transcript_df['word_count'] = utterance_word_counts

# Let's take a look at our dataframe to see the new columns.
transcript_df.sample(3)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#      Unnamed: 0 timestamp        speaker  \
# 789         789  01:08:02   Tessel Pluym
# 674         674  00:59:34  Sarah Duister
# 121         121  00:07:24  Sarah Duister
#
#                                              utterance  \
# 789  In some situations, maybe like they are becaus...
# 674                                  Yeah, yeah, yeah.
# 121  Ways to improve safety are putting up more lig...
#
#                                       utterance_tokens  word_count
# 789  [In, some, situations, ,, maybe, like, they, a...          27
# 674                        [Yeah, ,, yeah, ,, yeah, .]           6
# 121  [Ways, to, improve, safety, are, putting, up, ...          13

# %%
# Let's use an eariler variable we established to get a non-repeating list of speakers.

speaker_names = turns_df['Speaker'].to_list()
speaker_word_counts = []

for speaker_name in speaker_names :
    speaker_df = transcript_df[transcript_df['speaker'] == speaker_name]
    speaker_wc = speaker_df['word_count'].sum()
    speaker_word_counts.append(speaker_wc)

if "Word Count" not in turns_df.columns :
    turns_df.insert(2, "Word Count", speaker_word_counts)
turns_df
# Out:
#          Speaker  Turns  Word Count
# 0  Sarah Duister    442        3993
# 1   Jasmijn Miog    337        3906
# 2   Tessel Pluym    372        5313

# %% [markdown]
# Let's try that plot again, this time with word counts.

# %%
plt.figure(figsize=(figure_width, figure_height))
g = sns.barplot(data=turns_df, x="Word Count", y="Speaker", color='gray')

# %% [markdown]
# You can also try plotting the relationship between the turns and the word counts.
#
# Is the relationship linear? How else would you analyse turns vs words spoken?

# %%
# sns.scatterplot(data=turns_df, x="Word Count", y="Turns", color="gray")

from seaborn import axes_style
import seaborn.objects as so
so.Plot.config.theme.update(axes_style("white"))
p = so.Plot(data=turns_df, x="Word Count", y="Turns", text='Speaker').add(so.Dot(marker='o')).add(so.Text(halign='left')).show()

# %% [markdown]
# ## Dictionary Categories
# As you may have gathered from the reading assignments, dictionary categories in LIWC each have a list of words associated with that particular psycholinguistic process. For our example, let's look at the category `tentat` which indicates "tentativeness", often associated in design discussions with the proposal of an idea or a softening of judgement.
#
# Let's first load the words in this category via a file that I have created for you.

# %%
with open('/content/tentative (1).txt', 'r') as fo:
    dictionary_terms_list = fo.readlines()

# We get rid of extraneous carriage return (\n) characters from the text
dictionary_terms_list = [w.strip('\n') for w in dictionary_terms_list]
print(dictionary_terms_list)
# Out:
# ['allege*', 'almost', 'ambigu*', 'ambivalen*', 'any', 'anybod*', 'anyhow', 'anyone*', 'anything', 'anytime*', 'anywhere*', 'apparently', 'appears', 'apprehens*', 'approximat*', 'arbitrary*', 'assum*', 'assumed', 'barely', 'bet', 'bets', 'broadly', 'chance', 'chances', 'confus*', 'confuse', 'confuses', 'confusing', 'contingen*', 'debatable', 'depend', 'depended', 'depending', 'depends', 'doubt*', 'doubted', 'doubtful', 'doubtless*', 'dubious', 'dubiously', 'dunno', 'estimat*', 'fairly', 'feasib', 'feasible', 'generally', 'guess*', 'guessed', 'guesses', 'guessing', 'hardly', 'hazarding', 'hazy', 'hesita*', 'hope', 'hoped', 'hopeful*', 'hopefully', 'hopes', 'hoping', 'hypothes*', 'hypothetic*', 'if', 'iirc', 'imo', 'indecis*', 'indefinit*', 'indirect*', "isn't sure", 'kind of', 'kinda', 'kindof', 'largely', 'likel*', 'likely', 'loosely', 'marginal*', 'may', 'mayb', 'maybe', 'might', "might'nt", "might've", "mightn't", 'mightve', 'mildly', 'mostly', 'myster*', 'mysterious', 'mysteriously', 'nearly', 'no idea', 'not a bad idea', 'not all', 'not always', 'not certain*', 'not even sure', 'not exactly', 'not particular*', 'not precise*', 'not quite', 'not quite sure', 'not really', 'not really sure', 'not so far', 'not so much', 'not so sure', 'not specific*', 'not sure', 'obscur*', 'occasional', 'occasional*', 'often', 'option*', 'or', 'partly', 'perhaps', 'possib*', 'possible', 'possibly', 'potential', 'potentially', 'practically', 'pretty', 'probab*', 'probable', 'probably', 'prolly', 'puzzled', 'puzzlement', 'puzzling', 'question', 'questioned', 'questioning', 'questions', 'quite', 'random', 'randomly', 'randomness', 'rather', 'reportedly', 'roughly', "s'pose", 'seem', 'seemed', 'seeming', 'seeming*', 'seems', 'skeptic*', 'somebod*', 'someday', 'somehow', 'someone*', 'something*', 'sometime', 'sometimes', 'somewhat', 'somewhere', 'sort of', 'sorta', 'sortof', 'sorts', 'spose', 'suppose', 'supposed', 'supposedly', 'supposes', 'supposing', 'supposition*', 'tentativ*', 'typically', 'uncertain', 'uncertain*', 'unclear*', 'undecided', 'undecided*', 'undetermin*', 'unknowing', 'unknowingly', 'unknown', 'unresolv*', 'unsettl*', 'unsure', 'usually', 'vague', 'vague*', 'vaguely', 'volatil*', "wasn't sure", 'wavering*', "weren't sure", 'wonder', 'wondered', 'wondering', 'wonders', 'yet', "*'nt a bad idea", "*'nt all", "*'nt always", "*'nt certain*", "*'nt even sure", "*'nt exactly", "*'nt particular*", "*'nt precise*", "*'nt quite", "*'nt quite sure", "*'nt really", "*'nt really sure", "*'nt so far", "*'nt so much", "*'nt so sure", "*'nt specific*", "*'nt sure", "*n't a bad idea", "*n't all", '*nit always', "*n't certain*", "*n't even sure", "*n't exactly", "*n't particular*", "*n't precise*", "*n't quite", "*n't quite sure", "*n't really", "*n't really sure", "*n't so far", "*n't so much", "*n't so sure", "*n't specific*", "*n't sure"]

# %% [markdown]
# ## Finding matches between dictionary and text
# The next step is to find how many terms from the text match the terms in the dictionary category, and to count every match. Note that I use the word "term" and not "word", since there are a number of multi-word terms in the dictionary, such as `kind of`.
#
# There are also some wildcards, indicated by `*`. A wildcard character indicates a general pattern. For instance, `option*` will return a match to `option`, `options`, `optional`, and `optionally`.
#
# Due to these wildcards and multi-word terms, we cannot simply use a token-by-token match to perform dictionary term matching. Instead, we will have to find patterns in the original text that match the patterns indicated in the dictionary entries. This includes single- and multi-word terms as well as terms that use wildcards. To achieve this, we will use a concept called [**regular expressions**](https://en.wikipedia.org/wiki/Regular_expression). In python, regular expressions are largely implemented using the ["`re`" library](https://docs.python.org/3/howto/regex.html#regex-howto).

# %%
import re

def count_matches(text, pattern):
    if pattern.startswith('*') :
        pattern = r"[A-Za-z]*" + pattern[1:]

    if pattern.endswith('*') :
        pattern = pattern[:-1] + r"[A-Za-z]*'"

    m = r"\b" + pattern + r"\b"
    matches = re.findall(pattern, text)
    return len(matches)

# %% [markdown]
# The above function that we have written, called `count_matches` looks for a given single- or multi-word pattern and returns the number of matches in a given text.
#
# See the example below for a demonstration of this code.

# %%
test = "or sort sort of like make a... yeah. like some sort of video."
num_matches = count_matches(test, 'sort of')
print("Number of matches:", num_matches)
# Out:
# Number of matches: 2

# %%
dict_term_counts = [0] * transcript_df.shape[0]

for ind, utterance in enumerate(utterances_list) :
    for dict_term in dictionary_terms_list :
        term_counts_in_utterance = count_matches(utterance.lower(), dict_term)
        dict_term_counts[ind] += term_counts_in_utterance

transcript_df["tentat_counts"] = dict_term_counts
transcript_df.sample(3)
# Out:
#      Unnamed: 0 timestamp        speaker  \
# 886         886  01:19:26  Sarah Duister
# 507         507  00:37:18  Sarah Duister
# 763         763  01:06:29   Jasmijn Miog
#
#                                              utterance  \
# 886  Might be nice for the presentation to have to ...
# 507                                              Yeah.
# 763              I think that's the main main tension.
#
#                                       utterance_tokens  word_count  \
# 886  [Might, be, nice, for, the, presentation, to, ...          19
# 507                                          [Yeah, .]           2
# 763  [I, think, that, 's, the, main, main, tension, .]           9
#
#      tentat_counts
# 886              2
# 507              0
# 763              0

# %%
def dict_term_score(dict_term_counts, word_count):
    dict_score = dict_term_counts/word_count
    return dict_score

transcript_df['liwc_tentat_score'] = transcript_df.apply(lambda x: dict_term_score(x['tentat_counts'], x['word_count']), axis=1)
transcript_df.sample(5)
# Out:
#      Unnamed: 0 timestamp        speaker  \
# 250         250  00:16:54  Sarah Duister
# 848         848  01:14:06  Sarah Duister
# 369         369  00:26:51   Jasmijn Miog
# 715         715  01:03:02  Sarah Duister
# 984         984  01:30:38   Jasmijn Miog
#
#                                              utterance  \
# 250                  Between protecting public safety.
# 848  I kind of liked the direction of ehm. Changing...
# 369               In altar eyes gatherings, all right.
# 715               Yeah, but like I said earlier. Like.
# 984  What do we want to choose? Do we? Because I th...
#
#                                       utterance_tokens  word_count  \
# 250           [Between, protecting, public, safety, .]           5
# 848  [I, kind, of, liked, the, direction, of, ehm, ...          26
# 369    [In, altar, eyes, gatherings, ,, all, right, .]           8
# 715  [Yeah, ,, but, like, I, said, earlier, ., Like...          10
# 984  [What, do, we, want, to, choose, ?, Do, we, ?,...          22
#
#      tentat_counts  liwc_tentat_score
# 250              1           0.200000
# 848              1           0.038462
# 369              0           0.000000
# 715              0           0.000000
# 984              0           0.000000

# %%
tentat_df = transcript_df[transcript_df['liwc_tentat_score'] > 0]
print("Number of speech turns with a tentativeness score above zero:", tentat_df.shape[0])
# Out:
# Number of speech turns with a tentativeness score above zero: 393

# %%
dict_matches_for_speakers = []

for speaker_name in speaker_names :
    speaker_df = transcript_df[transcript_df['speaker'] == speaker_name]
    speech = ' '.join(speaker_df['utterance'].to_list()).lower()
    dict_matches = 0
    for dict_term in dictionary_terms_list :
        term_counts_in_utterance = count_matches(speech, dict_term)
        dict_matches += term_counts_in_utterance
    dict_matches_for_speakers.append(dict_matches)

if "Tentative Words" not in turns_df.columns :
    turns_df.insert(3, "Tentative Words", dict_matches_for_speakers)
if "Tentativeness Score" not in turns_df.columns :
    turns_df["Tentativeness Score"] = turns_df["Tentative Words"] / turns_df["Word Count"]
turns_df
# Out:
#          Speaker  Turns  Word Count  Tentative Words  Tentativeness Score
# 0  Sarah Duister    442        3993              291             0.072878
# 1   Jasmijn Miog    337        3906              259             0.066308
# 2   Tessel Pluym    372        5313              421             0.079240

# %% [markdown]
# ### Save your results!
# You can save your results as an excel file.

# %%
transcript_df.to_excel('/content/Saved analysed transcript.xlsx')

# %% [markdown]
# ### Concordance Analysis
# Since dictionary-based scores are not sensitive to the contexts of word use, it might be a good idea to examine the contexts of word use.
#
# For this purpose, we use a **KWIC** or **K**ey**W**ord **I**n **C**ontext view that shows all occurrences of a word of interest in the context of its surrounding text.

# %%
from nltk.text import Text
transcript_text = ' '.join(transcript_df['utterance'].to_list()).lower()
tokens = word_tokenize(transcript_text)
textList = Text(tokens)

for term in dictionary_terms_list :
    print("Looking for occurrences of", term, "...")
    textList.concordance(term, width=85, lines=25)
# Out:
# Looking for occurrences of allege* ...
# no matches
# Looking for occurrences of almost ...
# Displaying 4 of 4 matches:
# ne in her running , so she wants to go almost everyday , but she also has a job so s
# s and open spaces , i think that it is almost too obvious or something . yeah . that
# h when you bike here . yeah . everyone almost knows them and are like familiar with
#  scared of them , you feel you 'd feel almost safer if you see them because you 're
# Looking for occurrences of ambigu* ...
# no matches
# Looking for occurrences of ambivalen* ...
# no matches
# Looking for occurrences of any ...
# Displaying 5 of 5 matches:
# king on him and he feels judged . yeah . any thoughts ? ways to improve safety are pu
# reness and engage residents in reporting any suspicious behaviour . while these measu
# reness and engage residents in reporting any suspicious behavior . morning . so i. ma
# und you . so it 's harder to be aware of any potential danger . and . she feels safe
# when you talk to them , it does n't make any sense at all of what they 're saying , o
# Looking for occurrences of anybod* ...
# no matches
# Looking for occurrences of anyhow ...
# no matches
# Looking for occurrences of anyone* ...
# no matches
# Looking for occurrences of anything ...
# Displaying 6 of 6 matches:
# eah . most of them do n't really have anything to do . ok. ok , so i think these are
# . where you , like , reward them with anything . yeah , like either food or drinks o
# and they never . they never really do anything . they just hang out , yeah . no , th
# like litter because you 're consuming anything and there 's no nowhere to throw it a
# have to like take off requirements or anything it ’ s more like . tested . how does
# e . so now we 're not really changing anything about the park but more of like the p
# Looking for occurrences of anytime* ...
# no matches
# Looking for occurrences of anywhere* ...
# no matches
# Looking for occurrences of apparently ...
# no matches
# Looking for occurrences of appears ...
# no matches
# Looking for occurrences of apprehens* ...
# no matches
# Looking for occurrences of approximat* ...
# no matches
# Looking for occurrences of arbitrary* ...
# no matches
# Looking for occurrences of assum* ...
# no matches
# Looking for occurrences of assumed ...
# no matches
# Looking for occurrences of barely ...
# no matches
# Looking for occurrences of bet ...
# no matches
# Looking for occurrences of bets ...
# no matches
# Looking for occurrences of broadly ...
# no matches
# Looking for occurrences of chance ...
# no matches
# Looking for occurrences of chances ...
# no matches
# Looking for occurrences of confus* ...
# no matches
# Looking for occurrences of confuse ...
# no matches
# Looking for occurrences of confuses ...
# no matches
# Looking for occurrences of confusing ...
# Displaying 1 of 1 matches:
#  parks that have complex pathways and confusing layouts can make it difficult for peo
# Looking for occurrences of contingen* ...
# no matches
# Looking for occurrences of debatable ...
# no matches
# Looking for occurrences of depend ...
# no matches
# Looking for occurrences of depended ...
# no matches
# Looking for occurrences of depending ...
# no matches
# Looking for occurrences of depends ...
# Displaying 1 of 1 matches:
#  a good way . yeah . yeah , it sort of depends . maybe we can , since it 's more of a
# Looking for occurrences of doubt* ...
# no matches
# Looking for occurrences of doubted ...
# no matches
# Looking for occurrences of doubtful ...
# no matches
# Looking for occurrences of doubtless* ...
# no matches
# Looking for occurrences of dubious ...
# no matches
# Looking for occurrences of dubiously ...
# no matches
# Looking for occurrences of dunno ...
# no matches
# Looking for occurrences of estimat* ...
# no matches
# Looking for occurrences of fairly ...
# no matches
# Looking for occurrences of feasib ...
# no matches
# Looking for occurrences of feasible ...
# no matches
# Looking for occurrences of generally ...
# Displaying 1 of 1 matches:
# with the families for children . they generally feel safe in the park . but they like
# Looking for occurrences of guess* ...
# no matches
# Looking for occurrences of guessed ...
# no matches
# Looking for occurrences of guesses ...
# no matches
# Looking for occurrences of guessing ...
# Displaying 1 of 1 matches:
# ird behaviour . what is ? yeah , i 'm guessing tourists are bit lost in the park and
# Looking for occurrences of hardly ...
# no matches
# Looking for occurrences of hazarding ...
# no matches
# Looking for occurrences of hazy ...
# no matches
# Looking for occurrences of hesita* ...
# no matches
# Looking for occurrences of hope ...
# no matches
# Looking for occurrences of hoped ...
# no matches
# Looking for occurrences of hopeful* ...
# no matches
# Looking for occurrences of hopefully ...
# no matches
# Looking for occurrences of hopes ...
# no matches
# Looking for occurrences of hoping ...
# no matches
# Looking for occurrences of hypothes* ...
# no matches
# Looking for occurrences of hypothetic* ...
# no matches
# Looking for occurrences of if ...
# Displaying 25 of 56 matches:
# hen blue . yeah , yeah . all right . and if we get started , we can add joep ’ s aft
# group . yeah , because they 're not sure if there are a lot of values here . i think
#  yeah , they do , but . but not really . if it 's concerning to park or more their r
#  , what did you say ? that she will find if she if she in the park , she will find t
#  did you say ? that she will find if she if she in the park , she will find the well
#  improve the feeling . of safety . maybe if all the stakeholders said that we should
# e fetty falls that are in the park . and if he thinks it 's annoying . but he really
# r him . ok. yeah , i 've . yeah . look , if i missed something , but i think this is
# ly morning and in the late evening . and if they implement safety measures , they in
# yeah as . there 's plenty of space , and if there was more feasibility , she would f
# n with the natural environment . so like if you have safety interventions , they ble
#  same time social control . oh yeah , so if you have everyone like encouraged to loo
#  preserving personal freedom . yeah . so if you have a lot of patrol , it 's will al
# necks . yeah . so that kind of goes away if there are more rules or more cameras and
# that , yeah . because it 's the question if in your proposal you if you want to get
#  's the question if in your proposal you if you want to get the homeless people out
# s the homeless people in your city , and if you het them out of your park , they go
# r to the first one with the monitoring , if there 's police everywhere , it could di
# scape . and is there something else ? so if we consider the tensions and the things
# of the more general things that people , if people feel like they are hidden , like
#  people feel like they are hidden , like if they 're walking between the trees , tha
# es always attracts more attention , even if something happens . yeah , but then you
# at night they do n't . feel safe because if you think about what 's the goal of a pa
# rk just to do that there . i do n't know if that is the solution ? more rules and op
# so that 's . true . because also i think if you have . the people involved , you kno
# Looking for occurrences of iirc ...
# no matches
# Looking for occurrences of imo ...
# no matches
# Looking for occurrences of indecis* ...
# no matches
# Looking for occurrences of indefinit* ...
# no matches
# Looking for occurrences of indirect* ...
# no matches
# Looking for occurrences of isn't sure ...
# no matches
# Looking for occurrences of kind of ...
# no matches
# Looking for occurrences of kinda ...
# no matches
# Looking for occurrences of kindof ...
# no matches
# Looking for occurrences of largely ...
# no matches
# Looking for occurrences of likel* ...
# no matches
# Looking for occurrences of likely ...
# no matches
# Looking for occurrences of loosely ...
# no matches
# Looking for occurrences of marginal* ...
# no matches
# Looking for occurrences of may ...
# Displaying 5 of 5 matches:
#  he realize in the interview that people may be scared of him ? yeah , yeah . that 's
# outh or teenager who got associated with may feel labelled as unsafe or faced with th
# it is possible that further improvements may be necessary . partnerships with local c
# eriencing homelessness , homeless people may use parks as a place to rest and find re
# rnoons , when the crowd slims out , they may feel a little uneasy . the secluded area
# Looking for occurrences of mayb ...
# no matches
# Looking for occurrences of maybe ...
# Displaying 25 of 99 matches:
# ew results , right ? yes . so should we maybe ? discuss all the results from the inte
# terviews we did and then see what the . maybe we can like write down the key insights
#  them . yeah . you like , like , yeah , maybe maybe like one person use the sticky no
# . yeah . you like , like , yeah , maybe maybe like one person use the sticky note and
#  start . and then , yeah , i think that maybe it 's a good idea . so we can just star
#  idea . so we can just start at the top maybe . yeah . should i start ? yes . alright
# o ? yeah , that 's that might be nice . maybe just in brackets or something ? so i. i
# ese people in one sticky note or ? no . maybe we can like group it like the values or
# we can like group it like the values or maybe the positive the negatives and then oth
# tive 's . yeah . wait , you can also do maybe just . oh , yeah , yeah , yeah . values
# cause behind that is safety . yeah . so maybe yeah . so maybe we need values and posi
# t is safety . yeah . so maybe yeah . so maybe we need values and positives . yeah , i
# way of life is spending useful junk and maybe scratching it up or selling it . so it
# t 's a positive i think . yeah . yeah , maybe like . what he said that he keeps out o
#  that could be a good insight as well . maybe in the negatives or other , it 's just
#  positive negative and value in other . maybe we should structure differently for thi
# ark or more their role . yeah , i think maybe based on their . their job or their att
# personal freedom . that 's a good value maybe yeah . wait , what did you say ? a bala
#  people 's behavior in a negative way . maybe also value right or negative ? or negat
# n . wait what . loitering , loitering . maybe that means , like , the like the hangjo
# t can improve the feeling . of safety . maybe if all the stakeholders said that we sh
# y suspicious behavior . morning . so i. maybe we have to think about what their value
# eople are very aware of the safety , so maybe they see more and therefore feel more u
# re 's a community around . the safety . maybe people will feel more safe because more
# they feel but also make them more alert maybe . ok. so then we have ups . should n't
# Looking for occurrences of might ...
# Displaying 3 of 3 matches:
# r we just want to ? yeah , that 's that might be nice . maybe just in brackets or som
# rections . yeah . so . ehm . visitors . might be nice for the presentation to have to
# when they collaborate together and they might get to know each other . and that way t
# Looking for occurrences of might'nt ...
# no matches
# Looking for occurrences of might've ...
# no matches
# Looking for occurrences of mightn't ...
# no matches
# Looking for occurrences of mightve ...
# no matches
# Looking for occurrences of mildly ...
# no matches
# Looking for occurrences of mostly ...
# Displaying 2 of 2 matches:
# . oh , good one . no . yeah . they are mostly not there when it 's dark because it '
# g and early mornings . the reports are mostly included vandalism , littering , noise
# Looking for occurrences of myster* ...
# no matches
# Looking for occurrences of mysterious ...
# no matches
# Looking for occurrences of mysteriously ...
# no matches
# Looking for occurrences of nearly ...
# no matches
# Looking for occurrences of no idea ...
# no matches
# Looking for occurrences of not a bad idea ...
# no matches
# Looking for occurrences of not all ...
# no matches
# Looking for occurrences of not always ...
# no matches
# Looking for occurrences of not certain* ...
# no matches
# Looking for occurrences of not even sure ...
# no matches
# Looking for occurrences of not exactly ...
# no matches
# Looking for occurrences of not particular* ...
# no matches
# Looking for occurrences of not precise* ...
# no matches
# Looking for occurrences of not quite ...
# no matches
# Looking for occurrences of not quite sure ...
# no matches
# Looking for occurrences of not really ...
# no matches
# Looking for occurrences of not really sure ...
# no matches
# Looking for occurrences of not so far ...
# no matches
# Looking for occurrences of not so much ...
# no matches
# Looking for occurrences of not so sure ...
# no matches
# Looking for occurrences of not specific* ...
# no matches
# Looking for occurrences of not sure ...
# no matches
# Looking for occurrences of obscur* ...
# no matches
# Looking for occurrences of occasional ...
# Displaying 2 of 2 matches:
# g make them nervous . i also noticed occasional litter or sides of vandalism , which
#  makes me feel exposed . i also hear occasional stories about harassment , which alw
# Looking for occurrences of occasional* ...
# no matches
# Looking for occurrences of often ...
# Displaying 1 of 1 matches:
# re difficult for her because it 's dark often , and it makes her feel less safe . usu
# Looking for occurrences of option* ...
# no matches
# Looking for occurrences of or ...
# Displaying 25 of 85 matches:
# ter them . cluster them ok. wait . yes , or do we want to come .. up with . oh , no
# a good idea . just do it based on that . or we had this like . how did we call them
#  so the insights into the sticky notes . or do we just ? want to talk about ? what w
# into interviews . yeah . yeah , we can . or . and then directly cluster them . yeah
# et group they are ? like homeless people or we just want to ? yeah , that 's that mi
# t might be nice . maybe just in brackets or something ? so i. interviewed homeless p
# s of all these people in one sticky note or ? no . maybe we can like group it like t
# ybe we can like group it like the values or maybe the positive the negatives and the
#  that . yeah , you can put it underneath or something , yeah . yeah , like this i go
# i guess the values that i saw . safety . or should values be like what he thinks is
# g useful junk and maybe scratching it up or selling it . so it 's also like . a park
# ing up trash , helping with directions , or keeping an eye out . thought that was fu
# e goes to parks instead of like shelters or food banks because he feels a bit judged
# ive because it 's not in ? park . yeah . or it 's like a positive because in the par
# ve because in the park he does feel safe or safer , yeah . yeah . but i think we alr
# insight as well . maybe in the negatives or other , it 's just like . and . yeah . o
#  , we 're . i did interview with a youth or teenager who got associated with may fee
# ociated with may feel labelled as unsafe or faced with themselves . and that was a p
# nd no teachers breathing down their neck or no parents . giving them chores . ok. th
#  that ? i think privacy , yeah . ok so . or . actually freedom , they feel free ther
# not really . if it 's concerning to park or more their role . yeah , i think maybe b
# i think maybe based on their . their job or their attitude towards . the situation .
#  a negative way . maybe also value right or negative ? or negative . oh yeah . so yo
# y . maybe also value right or negative ? or negative . oh yeah . so you 're saying t
#  people more aware of possible ? dangers or at a local community . dangerous . yeah
# Looking for occurrences of partly ...
# no matches
# Looking for occurrences of perhaps ...
# no matches
# Looking for occurrences of possib* ...
# no matches
# Looking for occurrences of possible ...
# Displaying 2 of 2 matches:
# afety . incidents in the park . it is possible that further improvements may be nece
# es n't that make people more aware of possible ? dangers or at a local community . d
# Looking for occurrences of possibly ...
# no matches
# Looking for occurrences of potential ...
# Displaying 3 of 3 matches:
#  . so it 's harder to be aware of any potential danger . and . she feels safe is when
# ah . which make it more difficult for potential criminals . what do you think that th
# ng there . the lack of visibility and potential for someone to approach unnoticed mak
# Looking for occurrences of potentially ...
# no matches
# Looking for occurrences of practically ...
# no matches
# Looking for occurrences of pretty ...
# no matches
# Looking for occurrences of probab* ...
# no matches
# Looking for occurrences of probable ...
# no matches
# Looking for occurrences of probably ...
# Displaying 3 of 3 matches:
# s . this stakeholder . yeah , because probably their value would be . that 's they ,
#  think so too . gon na be too complex probably . i think . 'cause some are , i think
# . people like to help there , so they probably also like to help out with this . lik
# Looking for occurrences of prolly ...
# no matches
# Looking for occurrences of puzzled ...
# no matches
# Looking for occurrences of puzzlement ...
# no matches
# Looking for occurrences of puzzling ...
# no matches
# Looking for occurrences of question ...
# Displaying 3 of 3 matches:
#  which are just neglected and make me question whether it 's being monitored properl
# eah . that , yeah . because it 's the question if in your proposal you if you want t
#  it out further ? oh , that 's a good question . i think , wait . let 's see . devel
# Looking for occurrences of questioned ...
# no matches
# Looking for occurrences of questioning ...
# no matches
# Looking for occurrences of questions ...
# no matches
# Looking for occurrences of quite ...
# Displaying 11 of 11 matches:
# nd . when it 's dark , she thinks it 's quite you 're quite vulnerable because it 's
# s dark , she thinks it 's quite you 're quite vulnerable because it 's difficult to s
# safe and feeling unsafe . i think it 's quite clear themes throughout everything . ye
# ample of like homeless people that have quite how people have quite a nice role in th
#  people that have quite how people have quite a nice role in the . in the assignment
# . do we want to future vision ? that 's quite nice . ehm , we could do it . owh . yea
#  park because then you see oh there are quite some people today that already have bee
# o now i think this one . yeah , this is quite a nice one , right ? but i think it cou
# eel like we 've already worked out both quite a bit . both interventions , you mean ?
# so maybe you have like . it 's actually quite nice because you have the full time mon
# nd not every homeless is very . i think quite a lot of them are mentally not so stabl
# Looking for occurrences of random ...
# no matches
# Looking for occurrences of randomly ...
# no matches
# Looking for occurrences of randomness ...
# no matches
# Looking for occurrences of rather ...
# Displaying 1 of 1 matches:
#  . ehm . yeah , save . maybe we should rather like ‘ laagdrempelig ’ . what is it in
# Looking for occurrences of reportedly ...
# no matches
# Looking for occurrences of roughly ...
# no matches
# Looking for occurrences of s'pose ...
# no matches
# Looking for occurrences of seem ...
# no matches
# Looking for occurrences of seemed ...
# no matches
# Looking for occurrences of seeming ...
# no matches
# Looking for occurrences of seeming* ...
# no matches
# Looking for occurrences of seems ...
# Displaying 1 of 1 matches:
# ches are in poor condition . the lights seems dimmer than it used to be . better main
# Looking for occurrences of skeptic* ...
# no matches
# Looking for occurrences of somebod* ...
# no matches
# Looking for occurrences of someday ...
# no matches
# Looking for occurrences of somehow ...
# no matches
# Looking for occurrences of someone* ...
# no matches
# Looking for occurrences of something* ...
# no matches
# Looking for occurrences of sometime ...
# no matches
# Looking for occurrences of sometimes ...
# Displaying 7 of 7 matches:
# es . ok. there are people . folks are sometimes starting trouble because they see the
# utine to walk in the mornings , and i sometimes meet friends or neighbours . they lik
# oach unnoticed make me feel exposed . sometimes i hear about incidents on the news wh
# e also feeling safe by those people ? sometimes when you 're like designing with incl
#  strategically or something . because sometimes when you 're in the park and you have
# hat they . i do n't know . like maybe sometimes you have like boards or something tha
#  always the answer . we also have ehm sometimes sounds of birds outside music boxes .
# Looking for occurrences of somewhat ...
# no matches
# Looking for occurrences of somewhere ...
# Displaying 4 of 4 matches:
# u het them out of your park , they go somewhere else . yes . so they go away . or you
# n return get something for it maybe . somewhere in the park , a space for them . oh ,
# n the youth or the homeless people go somewhere else and another problem is created .
# fine . until the break . i have to be somewhere at the the . hoe heet het ? oh . the
# Looking for occurrences of sort of ...
# no matches
# Looking for occurrences of sorta ...
# no matches
# Looking for occurrences of sortof ...
# no matches
# Looking for occurrences of sorts ...
# no matches
# Looking for occurrences of spose ...
# no matches
# Looking for occurrences of suppose ...
# no matches
# Looking for occurrences of supposed ...
# no matches
# Looking for occurrences of supposedly ...
# no matches
# Looking for occurrences of supposes ...
# no matches
# Looking for occurrences of supposing ...
# no matches
# Looking for occurrences of supposition* ...
# no matches
# Looking for occurrences of tentativ* ...
# no matches
# Looking for occurrences of typically ...
# no matches
# Looking for occurrences of uncertain ...
# no matches
# Looking for occurrences of uncertain* ...
# no matches
# Looking for occurrences of unclear* ...
# no matches
# Looking for occurrences of undecided ...
# no matches
# Looking for occurrences of undecided* ...
# no matches
# Looking for occurrences of undetermin* ...
# no matches
# Looking for occurrences of unknowing ...
# no matches
# Looking for occurrences of unknowingly ...
# no matches
# Looking for occurrences of unknown ...
# no matches
# Looking for occurrences of unresolv* ...
# no matches
# Looking for occurrences of unsettl* ...
# no matches
# Looking for occurrences of unsure ...
# Displaying 1 of 1 matches:
# ttle escapes from the city . they feel unsure about areas . about which areas are sa
# Looking for occurrences of usually ...
# Displaying 4 of 4 matches:
# en , and it makes her feel less safe . usually she thinks . a safe place to go . beca
# eah , but i think realistically people usually feel scared when there 's homeless peo
# rt of an odd number , i think . like 3 usually . then maybe about the natural ecosyst
# they reward in the way that they would usually do so , right . yeah . ok. we could ma
# Looking for occurrences of vague ...
# no matches
# Looking for occurrences of vague* ...
# no matches
# Looking for occurrences of vaguely ...
# no matches
# Looking for occurrences of volatil* ...
# no matches
# Looking for occurrences of wasn't sure ...
# no matches
# Looking for occurrences of wavering* ...
# no matches
# Looking for occurrences of weren't sure ...
# no matches
# Looking for occurrences of wonder ...
# no matches
# Looking for occurrences of wondered ...
# no matches
# Looking for occurrences of wondering ...
# no matches
# Looking for occurrences of wonders ...
# no matches
# Looking for occurrences of yet ...
# no matches
# Looking for occurrences of *'nt a bad idea ...
# no matches
# Looking for occurrences of *'nt all ...
# no matches
# Looking for occurrences of *'nt always ...
# no matches
# Looking for occurrences of *'nt certain* ...
# no matches
# Looking for occurrences of *'nt even sure ...
# no matches
# Looking for occurrences of *'nt exactly ...
# no matches
# Looking for occurrences of *'nt particular* ...
# no matches
# Looking for occurrences of *'nt precise* ...
# no matches
# Looking for occurrences of *'nt quite ...
# no matches
# Looking for occurrences of *'nt quite sure ...
# no matches
# Looking for occurrences of *'nt really ...
# no matches
# Looking for occurrences of *'nt really sure ...
# no matches
# Looking for occurrences of *'nt so far ...
# no matches
# Looking for occurrences of *'nt so much ...
# no matches
# Looking for occurrences of *'nt so sure ...
# no matches
# Looking for occurrences of *'nt specific* ...
# no matches
# Looking for occurrences of *'nt sure ...
# no matches
# Looking for occurrences of *n't a bad idea ...
# no matches
# Looking for occurrences of *n't all ...
# no matches
# Looking for occurrences of *nit always ...
# no matches
# Looking for occurrences of *n't certain* ...
# no matches
# Looking for occurrences of *n't even sure ...
# no matches
# Looking for occurrences of *n't exactly ...
# no matches
# Looking for occurrences of *n't particular* ...
# no matches
# Looking for occurrences of *n't precise* ...
# no matches
# Looking for occurrences of *n't quite ...
# no matches
# Looking for occurrences of *n't quite sure ...
# no matches
# Looking for occurrences of *n't really ...
# no matches
# Looking for occurrences of *n't really sure ...
# no matches
# Looking for occurrences of *n't so far ...
# no matches
# Looking for occurrences of *n't so much ...
# no matches
# Looking for occurrences of *n't so sure ...
# no matches
# Looking for occurrences of *n't specific* ...
# no matches
# Looking for occurrences of *n't sure ...
# no matches

# %%
# In case you are looking for a specific term:
specific_term = "anything"
textList.concordance(specific_term, width=85, lines=25)
# Out:
# Displaying 6 of 6 matches:
# eah . most of them do n't really have anything to do . ok. ok , so i think these are
# . where you , like , reward them with anything . yeah , like either food or drinks o
# and they never . they never really do anything . they just hang out , yeah . no , th
# like litter because you 're consuming anything and there 's no nowhere to throw it a
# have to like take off requirements or anything it ’ s more like . tested . how does
# e . so now we 're not really changing anything about the park but more of like the p
